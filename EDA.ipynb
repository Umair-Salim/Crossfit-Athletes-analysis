# %% [markdown]
# # Exploratory data Analysis
# **Steps:**
# - Basic EDA steps
# - Checking for outliers
# - checking correlation
# - Checking distribution
# - Plotting Points of Interest

# %% [markdown]
# ### Basic EDA

# %%
#import essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)
df = pd.read_csv('cleaned_athletes.csv')
df.drop(columns=['Unnamed: 0'],inplace=True)
df.head()
# Out:
#           region gender  age  height  weight  fran  helen  grace  filthy50  \
# 0  South Central   Male   24      68     180   126    449     86       988
# 1     South West   Male   31      67     150   244    486    294      1217
# 2   Mid Atlantic   Male   37      72     210   162    482    143      1243
# 3  Latin America   Male   25      71     180   193    498    146      1584
# 4         Europe   Male   27      69     192   147    480    100      1070
#
#    fgonebad  run400  run5k  candj  snatch  deadlift  backsq  pullups  \
# 0       425      58   1302    315     240       475     405       80
# 1       330      63   1268    230     175       410     330       42
# 2       366      66   1320    285     205       525     425       49
# 3       263      93   1406    260     225       405     320       30
# 4         0      67   1340    287     220       441     397       30
#
#            eat                   train                    background  \
# 0  normal diet  CF center and Non CFWO  Educational institute sports
# 1  normal diet      CF center and CFWO  Educational institute sports
# 2  normal diet      CF center and CFWO            Regular rec sports
# 3      no diet      CF center and CFWO                       Only CF
# 4      no diet               CF center  Educational institute sports
#
#   experience   schedule    howlong
# 0    Trainer  3+ a week  2-4 years
# 1    Trainer  3+ a week  2-4 years
# 2    Trainer  2x a week   4+ years
# 3    Trainer      Other  2-4 years
# 4    Trainer  3+ a week  2-4 years

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      1640 non-null   object
#  1   gender      1640 non-null   object
#  2   age         1640 non-null   int64
#  3   height      1640 non-null   int64
#  4   weight      1640 non-null   int64
#  5   fran        1640 non-null   int64
#  6   helen       1640 non-null   int64
#  7   grace       1640 non-null   int64
#  8   filthy50    1640 non-null   int64
#  9   fgonebad    1640 non-null   int64
#  10  run400      1640 non-null   int64
#  11  run5k       1640 non-null   int64
#  12  candj       1640 non-null   int64
#  13  snatch      1640 non-null   int64
#  14  deadlift    1640 non-null   int64
#  15  backsq      1640 non-null   int64
#  16  pullups     1640 non-null   int64
#  17  eat         1640 non-null   object
#  18  train       1640 non-null   object
#  19  background  1640 non-null   object
#  20  experience  1640 non-null   object
#  21  schedule    1640 non-null   object
#  22  howlong     1640 non-null   object
# dtypes: int64(15), object(8)
# memory usage: 294.8+ KB

# %%
df.describe()
# Out:
#                age        height       weight         fran         helen  \
# count  1640.000000  1.640000e+03  1640.000000  1640.000000   1640.000000
# mean     33.685976  5.184466e+03   181.454268   294.037805    609.985366
# std       7.044584  2.071402e+05    27.957374   394.574153    644.167292
# min      16.000000  3.000000e+00    80.000000    33.000000     60.000000
# 25%      29.000000  6.700000e+01   165.000000   174.000000    483.000000
# 50%      33.000000  7.000000e+01   183.000000   229.000000    539.500000
# 75%      38.000000  7.200000e+01   200.000000   315.000000    615.000000
# max      56.000000  8.388607e+06   350.000000  5940.000000  20827.000000
#
#                grace       filthy50        fgonebad         run400  \
# count    1640.000000    1640.000000     1640.000000    1640.000000
# mean      571.087805    1666.331707      998.092683     291.791463
# std     12052.089097    5481.636943    24806.229557    6753.796013
# min        30.000000      50.000000        0.000000       4.000000
# 25%       128.000000    1185.000000      291.000000      60.000000
# 50%       170.000000    1408.500000      330.000000      68.000000
# 75%       227.250000    1670.000000      383.000000      79.000000
# max    480480.000000  215400.000000  1000000.000000  272220.000000
#
#               run5k        candj       snatch     deadlift       backsq  \
# count  1.640000e+03  1640.000000  1640.000000  1640.000000  1640.000000
# mean   2.040324e+03   234.450000   181.564634   404.610366   330.768902
# std    2.642176e+04    76.760326    70.898019   107.115050   120.987606
# min    6.000000e+01   -45.000000     0.000000     0.000000     0.000000
# 25%    1.210000e+03   198.000000   150.000000   350.000000   275.000000
# 50%    1.320000e+03   236.000000   180.000000   415.000000   335.000000
# 75%    1.462000e+03   275.000000   215.000000   465.000000   385.000000
# max    1.071240e+06  1936.000000  1936.000000  1936.000000  3450.000000
#
#             pullups
# count  1.640000e+03
# mean   6.119716e+03
# std    2.462558e+05
# min   -1.000000e+00
# 25%    2.600000e+01
# 50%    3.650000e+01
# 75%    4.800000e+01
# max    9.972638e+06

# %% [markdown]
# ### Checking distributions

# %%
df.hist(figsize=(15,15))

# %%
#checking distribution of categorical variables
plt.figure(figsize=(18,18))
plt.subplot(3,3,1)
sns.barplot(x=df['eat'].value_counts().index,y=df['eat'].value_counts(),data=df)
plt.title('eat')
plt.xticks(rotation=45,fontsize=7)
plt.subplot(3,3,2)
sns.barplot(x=df['train'].value_counts().index,y=df['train'].value_counts(),data=df)
plt.title('train')
plt.xticks(rotation=45,fontsize=7)
plt.subplot(3,3,3)
sns.barplot(x=df['region'].value_counts().index,y=df['region'].value_counts(),data=df)
plt.title('region')
plt.xticks(rotation=45,fontsize=7)
plt.subplot(3,3,4)
sns.barplot(x=df['background'].value_counts().index,y=df['background'].value_counts(),data=df)
plt.title('background')
plt.xticks(rotation=45,fontsize=7)
plt.subplot(3,3,5)
sns.barplot(x=df['experience'].value_counts().index,y=df['experience'].value_counts(),data=df)
plt.title('experience')
plt.xticks(rotation=45,fontsize=7)
plt.subplot(3,3,6)
sns.barplot(x=df['schedule'].value_counts().index,y=df['schedule'].value_counts(),data=df)
plt.title('schedule')
plt.xticks(rotation=45,fontsize=7)
plt.subplot(3,3,7)
sns.barplot(x=df['howlong'].value_counts().index,y=df['howlong'].value_counts(),data=df)
plt.title('howlong')
plt.xticks(rotation=45,fontsize=7)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '2-4 years'),
#   Text(1, 0, '4+ years'),
#   Text(2, 0, '1-2 years'),
#   Text(3, 0, '6-12 months'),
#   Text(4, 0, 'Less than 6 months'),
#   Text(5, 0, 'Decline to answer')])

# %% [markdown]
# ### Checking for Outliers

# %%
boxplot = df[['height', 'weight', 'fran', 'helen', 'grace', 'filthy50', 'run400', 'run5k', 'candj', 'snatch', 'deadlift', 'backsq', 'pullups']]
#cretating loop top plot box plots
for i in boxplot.columns:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[i])
    plt.title(i)
    plt.show()

# %%
df = df[df['height'] < df['height'].max()]
df.shape
# Out:
# (1639, 23)

# %%
df.columns
# Out:
# Index(['region', 'gender', 'age', 'height', 'weight', 'fran', 'helen', 'grace',
#        'filthy50', 'fgonebad', 'run400', 'run5k', 'candj', 'snatch',
#        'deadlift', 'backsq', 'pullups', 'eat', 'train', 'background',
#        'experience', 'schedule', 'howlong'],
#       dtype='object')

# %%
#finding upper and lower limit for height
upper_limit = df['height'].mean() + 3*df['height'].std()
lower_limit = df['height'].mean() - 3*df['height'].std()
print(upper_limit,lower_limit)
# Out:
# 81.91241548924407 57.096736432659526

# %%
#dropping outliers using upper and lower limit
df = df[(df['height'] < upper_limit) & (df['height'] > lower_limit)]
df.shape
# Out:
# (1634, 23)

# %%
#finding outliers for rest of columns and then dropping them
## creating a function to find upper and lower limit then drop outliers
def find_outliers(df,col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3-q1
    lower_limit = q1 - 1.5*iqr
    upper_limit = q3 + 1.5*iqr
    df = df[(df[col] < upper_limit) & (df[col] > lower_limit)]
    return df

#calling function for each column
df = find_outliers(df,'weight')
df = find_outliers(df,'fran')
df = find_outliers(df,'helen')
df = find_outliers(df,'grace')
df = find_outliers(df,'filthy50')
df = find_outliers(df,'run400')
df = find_outliers(df,'run5k')
df = find_outliers(df,'candj')
df = find_outliers(df,'snatch')
df = find_outliers(df,'deadlift')
df = find_outliers(df,'backsq')
df = find_outliers(df,'pullups')
df.shape
# Out:
# (1257, 23)

# %% [markdown]
# ### Checking Correlation

# %%
correlation = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(correlation,annot=True,cmap='coolwarm')
plt.show()
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6832\825094722.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()

# %% [markdown]
# - Looking at the correlation heatmap we can see the amount of correlation each column has with other.
# - To further investigate the column which have any relationship with other columns we will plot them.
# - An interesting fact is that age has no significant correlation with any other column.

# %%
#checking correlation of Crossfit WODs with amount of weight lifted
plt.figure(figsize=(10,5))
sns.lmplot(x='height',y='weight',hue='gender',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - We can see that there is strong positive linear relationship between height and weight

# %%
plt.figure(figsize=(10,5))
sns.lmplot(x='height',y='candj',hue='gender',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lmplot(x='weight',y='candj',hue='gender',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - It is clear that wight and candj have a positive linear relationship

# %%
plt.figure(figsize=(10,5))
sns.lmplot(x='weight',y='deadlift',hue='gender',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lmplot(x='weight',y='backsq',hue='gender',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - We can confidently say that people with more weight can do more heavy lifting

# %% [markdown]
# ### Plotting and furthur exploring Points of Interest

# %%
wwo = df.groupby(['schedule'])[["candj","snatch","deadlift","backsq"]].mean()
wwo.T
# Out:
# schedule    1x a day   2x a week   3+ a week  Decline to answer       Other
# candj     231.563559  249.967480  255.685567         248.714286  242.328467
# snatch    178.036017  193.426829  199.932990         195.071429  185.788321
# deadlift  405.097458  425.959350  437.636598         416.214286  417.160584
# backsq    325.637712  349.910569  356.574742         344.214286  338.051095

# %%
# plot wwo
wwo.T.plot(kind='bar', figsize=(10,5))
plt.title('Weightlifting by Schedule')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# - This plot tells us that the more an athlete trains the more weight he can lift.

# %%
rwo=df.groupby('schedule')['fran','helen','grace','filthy50','run400','run5k'].mean()
rwo.T
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6832\4134493594.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rwo=df.groupby('schedule')['fran','helen','grace','filthy50','run400','run5k'].mean()
# schedule     1x a day    2x a week    3+ a week  Decline to answer  \
# fran       254.726695   212.959350   204.729381         197.428571
# helen      556.216102   522.951220   516.778351         481.857143
# grace      182.711864   160.512195   151.840206         136.714286
# filthy50  1453.004237  1338.849593  1308.069588        1238.857143
# run400      69.699153    66.390244    65.969072          64.142857
# run5k     1331.963983  1297.959350  1295.420103        1214.500000
#
# schedule        Other
# fran       232.562044
# helen      537.854015
# grace      175.766423
# filthy50  1404.430657
# run400      68.759124
# run5k     1326.306569

# %%
rwo.T.plot(kind='bar', figsize=(10,5))
plt.title('Cardio by Schedule')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
wew = df.groupby(['eat'])[["candj","snatch","deadlift","backsq"]].mean()
wew.T
# Out:
# eat       Decline to answer     no diet  normal diet  strict diet
# candj            235.461538  254.000000   241.259300   247.317757
# snatch           179.769231  198.623318   186.176149   192.327103
# deadlift         415.000000  432.390135   417.110503   427.252336
# backsq           333.307692  350.008969   339.164114   344.682243

# %%
wew.T.plot(kind='bar', figsize=(10,5))
plt.title('Weightlifting by Eating Habits')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# - As we can see people who do not maintain their diet have lifted mostly heavy Weights

# %%
reo=df.groupby('eat')['fran','helen','grace','filthy50','run400','run5k'].mean()
reo.T
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6832\2168315458.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   reo=df.groupby('eat')['fran','helen','grace','filthy50','run400','run5k'].mean()
# eat       Decline to answer      no diet  normal diet  strict diet
# fran             204.769231   220.242152   230.661926   225.028037
# helen            489.538462   533.322870   537.195842   521.775701
# grace            146.230769   160.103139   170.711160   158.878505
# filthy50        1268.923077  1365.843049  1386.676149  1345.383178
# run400            63.153846    66.040359    68.319475    66.841121
# run5k           1219.461538  1301.704036  1318.641138  1289.196262

# %%
reo.T.plot(kind='bar', figsize=(10,5))
plt.title('Cardio by Eating Habits')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# - Interestingly people with strict diet have finished their cardio in less time than people who do not maintain their diet

# %%
rwo = df.groupby(['region'])[["candj","snatch","deadlift","backsq"]].mean()
rwo.T
# Out:
# region        Africa        Asia   Australia  Canada East  Canada West  \
# candj     258.769231  239.692308  242.490196   232.750000      239.325
# snatch    200.076923  186.076923  188.843137   176.840909      188.725
# deadlift  459.076923  405.538462  420.274510   402.613636      414.200
# backsq    371.923077  341.538462  338.901961   322.613636      338.600
#
# region    Central East      Europe  Latin America  Mid Atlantic  \
# candj       245.305882  246.016129     245.000000    242.725275
# snatch      190.835294  190.322581     190.347826    188.197802
# deadlift    425.635294  438.209677     420.913043    419.901099
# backsq      346.647059  342.500000     336.130435    344.824176
#
# region    North Central  North East  North West  Northern California  \
# candj        247.200000  242.174312  244.694444           251.410959
# snatch       190.896552  187.541284  189.611111           193.821918
# deadlift     424.648276  415.944954  415.277778           434.136986
# backsq       346.724138  339.137615  334.888889           354.082192
#
# region    South Central  South East  South West  Southern California
# candj        250.878505  243.081081  238.364583           238.517647
# snatch       196.056075  185.675676  183.791667           186.388235
# deadlift     431.364486  418.358108  411.958333           405.305882
# backsq       349.906542  341.378378  335.822917           326.470588

# %%
rwo.T.plot(kind='bar', figsize=(15,5))
plt.title('Weightlifting by Region')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# - Alhtough africans are less in number but still they have lifted more weights than any athlete from any other regions

# %%
rro = df.groupby('region')['fran','helen','grace','filthy50','run400','run5k'].mean()
rro.T
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6832\2574858386.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rro = df.groupby('region')['fran','helen','grace','filthy50','run400','run5k'].mean()
# region         Africa         Asia    Australia  Canada East  Canada West  \
# fran       195.000000   241.692308   230.725490   257.409091      247.375
# helen      543.923077   556.153846   536.470588   572.318182      542.500
# grace      154.230769   174.769231   162.686275   192.272727      167.475
# filthy50  1380.461538  1535.000000  1359.372549  1453.545455     1412.125
# run400      61.923077    70.307692    67.078431    72.227273       68.650
# run5k     1301.230769  1279.230769  1292.431373  1355.704545     1341.075
#
# region    Central East       Europe  Latin America  Mid Atlantic  \
# fran        232.635294   219.419355     219.173913    216.879121
# helen       547.364706   508.661290     512.869565    525.153846
# grace       169.364706   169.096774     182.043478    164.142857
# filthy50   1405.588235  1301.290323    1357.869565   1355.934066
# run400       69.305882    65.967742      70.043478     68.153846
# run5k      1348.435294  1249.903226    1321.000000   1294.439560
#
# region    North Central   North East   North West  Northern California  \
# fran         225.055172   237.697248   225.347222           208.452055
# helen        536.517241   548.926606   515.138889           524.589041
# grace        162.186207   173.990826   162.833333           157.054795
# filthy50    1376.668966  1387.266055  1295.041667          1310.493151
# run400        65.937931    68.146789    66.583333            65.739726
# run5k       1310.137931  1301.504587  1278.736111          1301.328767
#
# region    South Central   South East   South West  Southern California
# fran         219.224299   234.891892   222.854167           238.352941
# helen        529.224299   541.412162   533.500000           528.776471
# grace        158.560748   164.040541   172.916667           180.964706
# filthy50    1355.028037  1440.168919  1370.072917          1418.976471
# run400        65.542056    69.006757    67.635417            70.411765
# run5k       1334.196262  1341.925676  1298.739583          1309.764706

# %%
rro.T.plot(kind='bar', figsize=(15,5))
plt.title('Cardio by Region')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
bwo = df.groupby(['background'])[["candj","snatch","deadlift","backsq"]].mean()
bwo.T
# Out:
# background  Decline to answer  Educational institute sports     Only CF  \
# candj              252.166667                    242.037975  224.804348
# snatch             196.666667                    187.616034  173.793478
# deadlift           433.666667                    417.763713  403.402174
# backsq             345.083333                    338.994374  319.163043
#
# background  Professional sports  Regular rec sports
# candj                257.790323          249.728947
# snatch               200.322581          192.657895
# deadlift             443.080645          426.197368
# backsq               362.370968          348.068421

# %%
bwo.T.plot(kind='bar', figsize=(15,5))
plt.title('Weightlifting by Background')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
bro = df.groupby('background')['fran','helen','grace','filthy50','run400','run5k'].mean()
bro.T
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6832\1203088205.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bro = df.groupby('background')['fran','helen','grace','filthy50','run400','run5k'].mean()
# background  Decline to answer  Educational institute sports      Only CF  \
# fran               208.750000                    228.917018   252.847826
# helen              485.916667                    534.509142   561.260870
# grace              155.583333                    165.829817   186.641304
# filthy50          1327.083333                   1375.116737  1454.032609
# run400              65.916667                     67.904360    73.391304
# run5k             1209.666667                   1311.776371  1359.032609
#
# background  Professional sports  Regular rec sports
# fran                 190.306452          227.244737
# helen                499.838710          535.865789
# grace                152.822581          168.989474
# filthy50            1270.016129         1385.031579
# run400                64.983871           66.557895
# run5k               1271.725806         1311.178947

# %%
bro.T.plot(kind='bar', figsize=(15,5))
plt.title('Cardio by Background')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
